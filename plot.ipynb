# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
metrics = np.load('perf_metrics.npy')
metrics = pd.DataFrame(metrics[:,1:], index=metrics[:,0], columns=['mean_episode_return', 'mean_action_value'])
metrics.index = metrics.index.map(int)
metrics.index.name = 'timestep'

# %%
metrics.plot(xticks=xrange(0, metrics.index[-1], 1000000), rot=45)
